# %%
## Python Web Scrap. Extracting data from web to get the 5 most popupar mathematicians from the list.
# https://realpython.com/python-web-scraping-practical-introduction/

# %%
# !python -m pip install --upgrade pip
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/c2/d7/90f34cb0d83a6c5631cf71dfe64cc1054598c843a92b400e55675cc2ac37/pip-18.1-py2.py3-none-any.whl (1.3MB)
# Installing collected packages: pip
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# Successfully installed pip-18.1
# distributed 1.21.8 requires msgpack, which is not installed.

# %%
# !pip install requests BeautifulSoup4
# Out:
# Requirement already satisfied: requests in c:\users\afduarte\appdata\local\continuum\anaconda3\lib\site-packages (2.18.4)
# Requirement already satisfied: BeautifulSoup4 in c:\users\afduarte\appdata\local\continuum\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\afduarte\appdata\local\continuum\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\afduarte\appdata\local\continuum\anaconda3\lib\site-packages (from requests) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\afduarte\appdata\local\continuum\anaconda3\lib\site-packages (from requests) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\afduarte\appdata\local\continuum\anaconda3\lib\site-packages (from requests) (2018.4.16)

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup

# %%
def simple_get(url):
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

# %%
def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)

# %%
def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %%
##from mathematicians import simple_get
raw_html = simple_get('https://realpython.com/blog/')
len(raw_html)
# Out:
# 270707

# %%
no_html = simple_get('https://realpython.com/blog/nope-not-gonna-find-it')
no_html is None
# Out:
# True

# %%
raw_html = simple_get('http://www.fabpedigree.com/james/mathmen.htm')
html = BeautifulSoup(raw_html, 'html.parser')
for i, li in enumerate(html.select('li')):
  print(i, li.text)
# Out:
# 0  Isaac Newton
#  Archimedes
#  Carl F. Gauss
#  Leonhard Euler
#  Bernhard Riemann
#
# 1  Archimedes
#  Carl F. Gauss
#  Leonhard Euler
#  Bernhard Riemann
#
# 2  Carl F. Gauss
#  Leonhard Euler
#  Bernhard Riemann
#
# 3  Leonhard Euler
#  Bernhard Riemann
#
# 4  Bernhard Riemann
#
# 5  Henri Poincaré
#  Joseph-Louis Lagrange
#  Euclid  of Alexandria
#  David Hilbert
#  Gottfried W. Leibniz
#
# 6  Joseph-Louis Lagrange
#  Euclid  of Alexandria
#  David Hilbert
#  Gottfried W. Leibniz
#
# 7  Euclid  of Alexandria
#  David Hilbert
#  Gottfried W. Leibniz
#
# 8  David Hilbert
#  Gottfried W. Leibniz
#
# 9  Gottfried W. Leibniz
#
# 10  Alexandre Grothendieck
#  Pierre de Fermat
#  Évariste Galois
#  John von Neumann
#  René Descartes
#
# 11  Pierre de Fermat
#  Évariste Galois
#  John von Neumann
#  René Descartes
#
# 12  Évariste Galois
#  John von Neumann
#  René Descartes
#
# 13  John von Neumann
#  René Descartes
#
# 14  René Descartes
#
# 15  Karl W. T. Weierstrass
#  Srinivasa Ramanujan
#  Hermann K. H. Weyl
#  Peter G. L. Dirichlet
#  Niels Abel
#
# 16  Srinivasa Ramanujan
#  Hermann K. H. Weyl
#  Peter G. L. Dirichlet
#  Niels Abel
#
# 17  Hermann K. H. Weyl
#  Peter G. L. Dirichlet
#  Niels Abel
#
# 18  Peter G. L. Dirichlet
#  Niels Abel
#
# 19  Niels Abel
#
# 20  Georg Cantor
#  Carl G. J. Jacobi
#  Brahmagupta
#  Augustin Cauchy
#  Arthur Cayley
#
# 21  Carl G. J. Jacobi
#  Brahmagupta
#  Augustin Cauchy
#  Arthur Cayley
#
# 22  Brahmagupta
#  Augustin Cauchy
#  Arthur Cayley
#
# 23  Augustin Cauchy
#  Arthur Cayley
#
# 24  Arthur Cayley
#
# 25  Emmy Noether
#  Pythagoras  of Samos
#  Aryabhata
#  Leonardo `Fibonacci'
#  William R. Hamilton
#
# 26  Pythagoras  of Samos
#  Aryabhata
#  Leonardo `Fibonacci'
#  William R. Hamilton
#
# 27  Aryabhata
#  Leonardo `Fibonacci'
#  William R. Hamilton
#
# 28  Leonardo `Fibonacci'
#  William R. Hamilton
#
# 29  William R. Hamilton
#
# 30  Apollonius  of Perga
#  Charles Hermite
#  Pierre-Simon Laplace
#  Carl Ludwig Siegel
#  Diophantus  of Alexandria
#
# 31  Charles Hermite
#  Pierre-Simon Laplace
#  Carl Ludwig Siegel
#  Diophantus  of Alexandria
#
# 32  Pierre-Simon Laplace
#  Carl Ludwig Siegel
#  Diophantus  of Alexandria
#
# 33  Carl Ludwig Siegel
#  Diophantus  of Alexandria
#
# 34  Diophantus  of Alexandria
#
# 35  Muhammed al-Khowârizmi
#  Richard Dedekind
#  Kurt Gödel
#  Bháscara (II) Áchárya
#  Felix Christian Klein
#
# 36  Richard Dedekind
#  Kurt Gödel
#  Bháscara (II) Áchárya
#  Felix Christian Klein
#
# 37  Kurt Gödel
#  Bháscara (II) Áchárya
#  Felix Christian Klein
#
# 38  Bháscara (II) Áchárya
#  Felix Christian Klein
#
# 39  Felix Christian Klein
#
# 40  Blaise Pascal
#  Élie Cartan
#  Archytas  of Tarentum
#  Godfrey H. Hardy
#  Alhazen ibn al-Haytham
#
# 41  Élie Cartan
#  Archytas  of Tarentum
#  Godfrey H. Hardy
#  Alhazen ibn al-Haytham
#
# 42  Archytas  of Tarentum
#  Godfrey H. Hardy
#  Alhazen ibn al-Haytham
#
# 43  Godfrey H. Hardy
#  Alhazen ibn al-Haytham
#
# 44  Alhazen ibn al-Haytham
#
# 45  Jean le Rond d'Alembert
#  F.E.J. Émile Borel
#  Julius Plücker
#  Hipparchus  of Nicaea
#  Andrey N. Kolmogorov
#
# 46  F.E.J. Émile Borel
#  Julius Plücker
#  Hipparchus  of Nicaea
#  Andrey N. Kolmogorov
#
# 47  Julius Plücker
#  Hipparchus  of Nicaea
#  Andrey N. Kolmogorov
#
# 48  Hipparchus  of Nicaea
#  Andrey N. Kolmogorov
#
# 49  Andrey N. Kolmogorov
#
# 50  Joseph Liouville
#  Eudoxus  of Cnidus
#  F. Gotthold Eisenstein
#  Jacob Bernoulli
#  Johannes Kepler
#
# 51  Eudoxus  of Cnidus
#  F. Gotthold Eisenstein
#  Jacob Bernoulli
#  Johannes Kepler
#
# 52  F. Gotthold Eisenstein
#  Jacob Bernoulli
#  Johannes Kepler
#
# 53  Jacob Bernoulli
#  Johannes Kepler
#
# 54  Johannes Kepler
#
# 55  Stefan Banach
#  Jacques Hadamard
#  Giuseppe Peano
#  Panini  of Shalatula
#  André Weil
#
# 56  Jacques Hadamard
#  Giuseppe Peano
#  Panini  of Shalatula
#  André Weil
#
# 57  Giuseppe Peano
#  Panini  of Shalatula
#  André Weil
#
# 58  Panini  of Shalatula
#  André Weil
#
# 59  André Weil
#
# 60  Jakob Steiner
#  Liu Hui
#  Gaspard Monge
#  Hermann G. Grassmann
#  François Viète
#
# 61  Liu Hui
#  Gaspard Monge
#  Hermann G. Grassmann
#  François Viète
#
# 62  Gaspard Monge
#  Hermann G. Grassmann
#  François Viète
#
# 63  Hermann G. Grassmann
#  François Viète
#
# 64  François Viète
#
# 65  M. E. Camille Jordan
#  Joseph Fourier
#  Bonaventura Cavalieri
#  Jean-Pierre Serre
#  Marius Sophus Lie
#
# 66  Joseph Fourier
#  Bonaventura Cavalieri
#  Jean-Pierre Serre
#  Marius Sophus Lie
#
# 67  Bonaventura Cavalieri
#  Jean-Pierre Serre
#  Marius Sophus Lie
#
# 68  Jean-Pierre Serre
#  Marius Sophus Lie
#
# 69  Marius Sophus Lie
#
# 70  Albert Einstein
#  Galileo Galilei
#  James C. Maxwell
#  Aristotle
#  Girolamo Cardano
#
# 71  Galileo Galilei
#  James C. Maxwell
#  Aristotle
#  Girolamo Cardano
#
# 72  James C. Maxwell
#  Aristotle
#  Girolamo Cardano
#
# 73  Aristotle
#  Girolamo Cardano
#
# 74  Girolamo Cardano
#
# 75  Michael F. Atiyah
#  Atle Selberg
#  L.E.J. Brouwer
#  Christiaan Huygens
#  Alan M. Turing
#
# 76  Atle Selberg
#  L.E.J. Brouwer
#  Christiaan Huygens
#  Alan M. Turing
#
# 77  L.E.J. Brouwer
#  Christiaan Huygens
#  Alan M. Turing
#
# 78  Christiaan Huygens
#  Alan M. Turing
#
# 79  Alan M. Turing
#
# 80  Jean-Victor Poncelet
#  Pafnuti Chebyshev
#  Henri Léon Lebesgue
#  John E. Littlewood
#  F. L. Gottlob Frege
#
# 81  Pafnuti Chebyshev
#  Henri Léon Lebesgue
#  John E. Littlewood
#  F. L. Gottlob Frege
#
# 82  Henri Léon Lebesgue
#  John E. Littlewood
#  F. L. Gottlob Frege
#
# 83  John E. Littlewood
#  F. L. Gottlob Frege
#
# 84  F. L. Gottlob Frege
#
# 85  Alfred Tarski
#  Shiing-Shen Chern
#  James J. Sylvester
#  Johann Bernoulli
#  Ernst E. Kummer
#
# 86  Shiing-Shen Chern
#  James J. Sylvester
#  Johann Bernoulli
#  Ernst E. Kummer
#
# 87  James J. Sylvester
#  Johann Bernoulli
#  Ernst E. Kummer
#
# 88  Johann Bernoulli
#  Ernst E. Kummer
#
# 89  Ernst E. Kummer
#
# 90  Johann H. Lambert
#  George Pólya
#  Felix Hausdorff
#  Siméon-Denis Poisson
#  Hermann Minkowski
#
# 91  George Pólya
#  Felix Hausdorff
#  Siméon-Denis Poisson
#  Hermann Minkowski
#
# 92  Felix Hausdorff
#  Siméon-Denis Poisson
#  Hermann Minkowski
#
# 93  Siméon-Denis Poisson
#  Hermann Minkowski
#
# 94  Hermann Minkowski
#
# 95  George D. Birkhoff
#  Omar al-Khayyám
#  Adrien M. Legendre
#  Pappus  of Alexandria
#  Thales  of Miletus
#
# 96  Omar al-Khayyám
#  Adrien M. Legendre
#  Pappus  of Alexandria
#  Thales  of Miletus
#
# 97  Adrien M. Legendre
#  Pappus  of Alexandria
#  Thales  of Miletus
#
# 98  Pappus  of Alexandria
#  Thales  of Miletus
#
# 99  Thales  of Miletus

# %%
def get_names():
    """
    Downloads the page where the list of mathematicians is found
    and returns a list of strings, one per mathematician
    """
    url = 'http://www.fabpedigree.com/james/mathmen.htm'
    response = simple_get(url)

    if response is not None:
        html = BeautifulSoup(response, 'html.parser')
        names = set()
        for li in html.select('li'):
            for name in li.text.split('\n'):
                if len(name) > 0:
                    names.add(name.strip())
        return list(names)

    # Raise an exception if we failed to get any data from the url
    raise Exception('Error retrieving contents at {}'.format(url))

# %%
def get_hits_on_name(name):
    """
    Accepts a `name` of a mathematician and returns the number
    of hits that mathematician's Wikipedia page received in the 
    last 60 days, as an `int`
    """
    # url_root is a template string that is used to build a URL.
    url_root = 'https://xtools.wmflabs.org/articleinfo/en.wikipedia.org/{}'
    response = simple_get(url_root.format(name))

    if response is not None:
        html = BeautifulSoup(response, 'html.parser')

        hit_link = [a for a in html.select('a')
                    if a['href'].find('latest-60') > -1]

        if len(hit_link) > 0:
            # Strip commas
            link_text = hit_link[0].text.replace(',', '')
            try:
                # Convert to integer
                return int(link_text)
            except:
                log_error("couldn't parse {} as an `int`".format(link_text))

    log_error('No pageviews found for {}'.format(name))
    return None

# %%
if __name__ == '__main__':
    print('Getting the list of names....')
    names = get_names()
    print('... done.\n')

    results = []

    print('Getting stats for each name....')

    for name in names:
        try:
            hits = get_hits_on_name(name)
            if hits is None:
                hits = -1
            results.append((hits, name))
        except:
            results.append((-1, name))
            log_error('error encountered while processing '
                      '{}, skipping'.format(name))

    print('... done.\n')

    results.sort()
    results.reverse()

    if len(results) > 5:
        top_marks = results[:5]
    else:
        top_marks = results

    print('\nThe most popular mathematicians are:\n')
    for (mark, mathematician) in top_marks:
        print('{} with {} pageviews'.format(mathematician, mark))

    no_results = len([res for res in results if res[0] == -1])
    print('\nBut we did not find results for '
          '{} mathematicians on the list'.format(no_results))
# Out:
# Getting the list of names....
# ... done.
#
# Getting stats for each name....
# No pageviews found for Peter G. L. Dirichlet
# No pageviews found for William R. Hamilton
# No pageviews found for Alhazen ibn al-Haytham
# No pageviews found for Adrien M. Legendre
# No pageviews found for F. L. Gottlob Frege
# No pageviews found for Ernst E. Kummer
# No pageviews found for F.E.J. Émile Borel
# No pageviews found for Hermann K. H. Weyl
# No pageviews found for James J. Sylvester
# No pageviews found for Panini  of Shalatula
# No pageviews found for Muhammed al-Khowârizmi
# No pageviews found for F. Gotthold Eisenstein
# No pageviews found for M. E. Camille Jordan
# No pageviews found for Karl W. T. Weierstrass
# No pageviews found for Leonardo `Fibonacci'
# No pageviews found for Bháscara (II) Áchárya
# No pageviews found for Hermann G. Grassmann
# No pageviews found for Omar al-Khayyám
# No pageviews found for Gottfried W. Leibniz
# ... done.
#
#
# The most popular mathematicians are:
#
# Albert Einstein with 1014719 pageviews
# Isaac Newton with 562451 pageviews
# Aristotle with 495648 pageviews
# Galileo Galilei with 408969 pageviews
# Srinivasa Ramanujan with 354970 pageviews
#
# But we did not find results for 19 mathematicians on the list
